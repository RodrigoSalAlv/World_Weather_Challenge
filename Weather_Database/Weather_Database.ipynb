# %%
# Import the dependencies.
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name


    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
cities
# Out:
# ['lavrentiya',
#  'mar del plata',
#  'illoqqortoormiut',
#  'bandarbeyla',
#  'vaini',
#  'chokurdakh',
#  'codrington',
#  'juxian',
#  'dzaoudzi',
#  'hobart',
#  'naze',
#  'wonthaggi',
#  'yar-sale',
#  'busselton',
#  'taburi',
#  'guarapari',
#  'chunoyar',
#  'butaritari',
#  'angoche',
#  'ribeira grande',
#  'rostaq',
#  'victoria',
#  'ercis',
#  'acapulco',
#  'nhulunbuy',
#  'menomonie',
#  'taolanaro',
#  'rikitea',
#  'simpang',
#  'san cristobal',
#  'kloulklubed',
#  'tsihombe',
#  'la union',
#  'ushuaia',
#  'new norfolk',
#  'solsvik',
#  'bethel',
#  'pavlodar',
#  'inuvik',
#  'vikindu',
#  'port hawkesbury',
#  'kudahuvadhoo',
#  'hilo',
#  'esperance',
#  'longyearbyen',
#  'porbandar',
#  'punta arenas',
#  'zhanaozen',
#  'arraial do cabo',
#  'kapaa',
#  'mahebourg',
#  'yellowknife',
#  'tabou',
#  'atuona',
#  'bluff',
#  'meyungs',
#  'kahului',
#  'hithadhoo',
#  'hermanus',
#  'lorengau',
#  'haines junction',
#  'guerrero negro',
#  'racaciuni',
#  'nikolskoye',
#  'gunjur',
#  'avera',
#  'katsuura',
#  'thaton',
#  'svetlyy',
#  'jamestown',
#  'severo-kurilsk',
#  'avarua',
#  'nome',
#  'krasnoselkup',
#  'ust-tsilma',
#  'gawler',
#  'yanan',
#  'sloboda',
#  'mataura',
#  'sola',
#  'vilyuysk',
#  'kaka',
#  'saint-philippe',
#  'upernavik',
#  'rokytne',
#  'nizhneyansk',
#  'kodiak',
#  'kruisfontein',
#  'vaitupu',
#  'barrow',
#  'jabiru',
#  'brae',
#  'tura',
#  'tasiilaq',
#  'mocuba',
#  'moissac',
#  'maniitsoq',
#  'upata',
#  'mitsamiouli',
#  'goroka',
#  'tres arroyos',
#  'namibe',
#  'vung tau',
#  'amderma',
#  'groningen',
#  'barcelona',
#  'victor harbor',
#  'attawapiskat',
#  'bambanglipuro',
#  'pafos',
#  'amurzet',
#  'znamenskoye',
#  'rocha',
#  'perth',
#  'metro',
#  'comodoro rivadavia',
#  'vallenar',
#  'carnarvon',
#  'lagoa',
#  'chapleau',
#  'coihaique',
#  'kamenskoye',
#  'gualaquiza',
#  'ostrovnoy',
#  'lompoc',
#  'labuhan',
#  'tezu',
#  'colac',
#  'shenkursk',
#  'abalak',
#  'san nicolas',
#  'yelan-kolenovskiy',
#  'alofi',
#  'taft',
#  'uribia',
#  'chapais',
#  'castro',
#  'duku',
#  'ponta do sol',
#  'albany',
#  'coahuayana',
#  'ketou',
#  'talnakh',
#  'pisco',
#  'turje',
#  'ca mau',
#  'east london',
#  'kijang',
#  'barentsburg',
#  'cairns',
#  'tuggurt',
#  'luderitz',
#  'catuday',
#  'khatanga',
#  'grindavik',
#  'vila velha',
#  'tuktoyaktuk',
#  'penzance',
#  'puerto ayora',
#  'kharian',
#  'inhambane',
#  'kavaratti',
#  'hualmay',
#  'sandusky',
#  'kintinku',
#  'torbay',
#  'koumac',
#  'bireun',
#  'tessalit',
#  'broome',
#  'ankpa',
#  'bontang',
#  'poso',
#  'prince rupert',
#  'cape town',
#  'peleduy',
#  'sioux lookout',
#  'burnie',
#  'chuy',
#  'varkkallai',
#  'pemberton',
#  'mys shmidta',
#  'saldanha',
#  'impfondo',
#  'moosomin',
#  'faanui',
#  'tiksi',
#  'hirara',
#  'west wendover',
#  'fortuna',
#  'jahrom',
#  'corozal',
#  'kumluca',
#  'antofagasta',
#  'borogontsy',
#  'ovsyanka',
#  'presidente dutra',
#  'egvekinot',
#  'kazanskaya',
#  'bredasdorp',
#  'trinidad',
#  'christchurch',
#  'forecariah',
#  'port elizabeth',
#  'tyup',
#  'kamaishi',
#  'ahipara',
#  'amuntai',
#  'leningradskiy',
#  'wanning',
#  'qarchi gak',
#  'elizabeth city',
#  'tahta',
#  'skjervoy',
#  'narsaq',
#  'vao',
#  'waipawa',
#  'lamar',
#  'qaanaaq',
#  'pointe-noire',
#  'solano',
#  'baoding',
#  'sibolga',
#  'tarko-sale',
#  'tukrah',
#  'bonavista',
#  'junin',
#  'thompson',
#  'teya',
#  'beringovskiy',
#  'provideniya',
#  'alice springs',
#  'souillac',
#  'vilhena',
#  'altay',
#  'gollere',
#  'adrar',
#  'vuktyl',
#  'basoko',
#  'bilibino',
#  'sukhobuzimskoye',
#  'belushya guba',
#  'callaway',
#  'klaksvik',
#  'pangai',
#  'la primavera',
#  'escanaba',
#  'margate',
#  'cabo san lucas',
#  'moree',
#  'puro',
#  'kirakira',
#  'kieta',
#  'taltal',
#  'chipinge',
#  'lexington',
#  'high level',
#  'valdivia',
#  'sentyabrskiy',
#  'gisborne',
#  'umm kaddadah',
#  'port alfred',
#  'san patricio',
#  'bargal',
#  'cidreira',
#  'quatre cocos',
#  'channel-port aux basques',
#  'tutoia',
#  'songling',
#  'ijaki',
#  'saskylakh',
#  'saint-georges',
#  'lishui',
#  'arman',
#  'gilgit',
#  'lebu',
#  'djougou',
#  'saint george',
#  'huilong',
#  'lolua',
#  'chara',
#  'ilulissat',
#  'pevek',
#  'healdsburg',
#  'robertson',
#  'naryan-mar',
#  'farah',
#  'ust-kut',
#  'nantucket',
#  'lhuntshi',
#  'soroti',
#  'liaocheng',
#  'homer',
#  'salalah',
#  'malwan',
#  'usinsk',
#  'mana',
#  'rincon',
#  'dombarovskiy',
#  'mandalgovi',
#  'whitehorse',
#  'hihifo',
#  'caxito',
#  'harper',
#  'namyslow',
#  'plettenberg bay',
#  'saint anthony',
#  'uige',
#  'biga',
#  'hobyo',
#  'takoradi',
#  'maragogi',
#  'urengoy',
#  'samusu',
#  'eskasem',
#  'kununurra',
#  'sur',
#  'itarema',
#  'broken hill',
#  'klyuchi',
#  'mehamn',
#  'veraval',
#  'georgetown',
#  'korkino',
#  'ucluelet',
#  'mackay',
#  'krasnoborsk',
#  'kangaatsiaq',
#  'staraya russa',
#  'aykhal',
#  'warwick',
#  'daxian',
#  'thai nguyen',
#  'cartagena del chaira',
#  'general pico',
#  'sitka',
#  'ust-nera',
#  'ye',
#  'viedma',
#  'hastings',
#  'vila do maio',
#  'milan',
#  'palmer',
#  'motygino',
#  'zonguldak',
#  'dikson',
#  'zlatoust',
#  'nouadhibou',
#  'owando',
#  'kilindoni',
#  'turukhansk',
#  'boundiali',
#  'mashhad',
#  'aswan',
#  'jiexiu',
#  'vacaria',
#  'hambantota',
#  'scarborough',
#  'bay roberts',
#  'yulara',
#  'kazalinsk',
#  'barawe',
#  'bathsheba',
#  'tettnang',
#  'maxixe',
#  'port hardy',
#  'vardo',
#  'monterey',
#  'anshun',
#  'norman wells',
#  'piedras negras',
#  'bollnas',
#  'nizhniy kuranakh',
#  'cadiz',
#  'las cruces',
#  'mozarlandia',
#  'bata',
#  'guararapes',
#  'matadi',
#  'hasaki',
#  'voiron',
#  'axim',
#  'manoharpur',
#  'tabiauea',
#  'biggar',
#  'cooma',
#  'northam',
#  'conceicao do araguaia',
#  'pitimbu',
#  'mount gambier',
#  'badarpur',
#  'clyde river',
#  'airai',
#  'atambua',
#  'aksaray',
#  'nanortalik',
#  'kalabo',
#  'iquitos',
#  'tiznit',
#  'rio grande',
#  'russell',
#  'biak',
#  'nahrin',
#  'pangnirtung',
#  'tecoanapa',
#  'smiltene',
#  'bulawayo',
#  'ayan',
#  'wahiawa',
#  'del rio',
#  'ekibastuz',
#  'lazaro cardenas',
#  'krasnogorodsk',
#  'graham',
#  'mildura',
#  'tautira',
#  'kendal',
#  'muroto',
#  'zyryanovsk',
#  'luanda',
#  'muros',
#  'hamilton',
#  'bilma',
#  'acajutla',
#  'westport',
#  'vytegra',
#  'panaba',
#  'cherlak',
#  'robertsport',
#  'zambezi',
#  'sokoni',
#  'tuatapere',
#  'marang',
#  'port lincoln',
#  'leh',
#  'bengkulu',
#  'geraldton',
#  'bang saphan',
#  'novikovo',
#  'steamboat springs',
#  'marawi',
#  'anadyr',
#  'nemuro',
#  'pekan',
#  'ndele',
#  'qui nhon',
#  'argelia',
#  'araouane',
#  'kargasok',
#  'malanje',
#  'asau',
#  'aracuai',
#  'jutai',
#  'venice',
#  'mount pleasant',
#  'coquimbo',
#  'fare',
#  'sretensk',
#  'mahajanga',
#  'caucasia',
#  'makushino',
#  'bojaya',
#  'makakilo city',
#  'boshnyakovo',
#  'lakes entrance',
#  'becerril',
#  'aklavik',
#  'peque',
#  'bajil',
#  'artyk',
#  'north berwick',
#  'bintulu',
#  'aleksandrovskiy zavod',
#  'san matias',
#  'kalanchak',
#  'kishi',
#  'tigil',
#  'bowen',
#  'ulundi',
#  'baghdad',
#  'sedelnikovo',
#  'iqaluit',
#  'kibiti',
#  'rossland',
#  'rosetta',
#  'port augusta',
#  'mataram',
#  'kerur',
#  'kaitangata',
#  'mulege',
#  'touros',
#  'erzin',
#  'lloydminster',
#  'mosquera',
#  'eyl',
#  'pacific grove',
#  'lagos',
#  'bom jardim',
#  'dingle',
#  'karratha',
#  'fort saint john',
#  'puerto leguizamo',
#  'vanimo',
#  'tatarsk',
#  'general roca',
#  'susangerd',
#  'kavieng',
#  'gravdal',
#  'lufilufi',
#  'maningrida',
#  'ust-kamchatsk',
#  'te anau',
#  'longlac',
#  'baykit',
#  'russkaya polyana',
#  'solvychegodsk',
#  'zhigansk',
#  'jiazi',
#  'campoverde',
#  'guiyang',
#  'pirgos',
#  'mackenzie',
#  'arlit',
#  'chumikan',
#  'gat',
#  'wenling',
#  'havelock',
#  'mecca',
#  'vila',
#  'mogadishu',
#  'tonantins',
#  'sharjah',
#  'umarkot',
#  'tamandare',
#  'gorno-chuyskiy',
#  'el wasta',
#  'praia',
#  'pemangkat',
#  'kota kinabalu',
#  'shingu',
#  'padang',
#  'dutse',
#  'ranau',
#  'hereford',
#  'belmonte',
#  'abha',
#  'portland',
#  'quepos',
#  'zhezkazgan',
#  'ibra',
#  'fevralsk',
#  'prado',
#  'mugla',
#  'ewa beach',
#  'cururupu',
#  'roald',
#  'soyo',
#  'mora',
#  'hailun',
#  'mujiayingzi',
#  'dunedin',
#  'baijiantan',
#  'cherskiy',
#  'elko',
#  'belyy yar',
#  'lalomanu',
#  'novyye burasy',
#  'rawson',
#  'haimen',
#  'kholtoson',
#  'burgas',
#  'dolbeau',
#  'viligili',
#  'severodvinsk',
#  'gedzhukh',
#  'safford',
#  'tambura',
#  'rapid valley',
#  'tiarei',
#  'cayenne',
#  'byron bay',
#  'galle',
#  'mongo',
#  'ituporanga',
#  'sechura',
#  'topolobampo',
#  'port blair',
#  'sao jose da coroa grande',
#  'port hope',
#  'nezahualcoyotl',
#  'nizwa',
#  'kumbo',
#  'baturaja',
#  'jacareacanga',
#  'yaan',
#  'sharkan',
#  'pau brasil',
#  'cape canaveral',
#  'grand gaube',
#  'doha',
#  'palabuhanratu',
#  'bharatpur',
#  'edirne',
#  'ngunguru',
#  'oktyabrskiy',
#  'balaipungut',
#  'nelson bay',
#  'lasa',
#  'kabansk',
#  'azimur',
#  'kushiro',
#  'mayo',
#  'columbus',
#  'port-gentil',
#  'bagdarin',
#  'kharan',
#  'hudson bay',
#  'richards bay',
#  'lugazi',
#  'vazhiny',
#  'sao filipe',
#  'alexandria',
#  'grand river south east',
#  'oranjestad',
#  'karangasem',
#  'kaa-khem',
#  'kangavar',
#  'asayita',
#  'auki',
#  'kaspiyskiy',
#  'dekoa',
#  'wladyslawowo',
#  'charlestown',
#  'sao paulo de olivenca',
#  'bolungarvik',
#  'inverell',
#  'tomatlan',
#  'babati',
#  'samarai',
#  'lingao',
#  'ancud',
#  'marystown',
#  'itoman',
#  'gorontalo',
#  'north bay',
#  'canico',
#  'kirchlengern',
#  'ust-maya',
#  'pimentel',
#  'tilichiki',
#  'benguela',
#  'emporia',
#  'yakima',
#  'la paz',
#  'natal',
#  'salinopolis',
#  'san ramon',
#  'khandyga',
#  'zachepylivka',
#  'guaranda',
#  'qaqortoq',
#  'morlaix',
#  'waingapu',
#  'senmonorom',
#  'urusha',
#  'dawson',
#  'shimoda',
#  'los llanos de aridane',
#  'rundu',
#  'tabuk',
#  'nandura',
#  'nyurba',
#  'nizhniy odes',
#  'muzhi',
#  'cotija',
#  'carmo do rio claro',
#  'meshchovsk',
#  'bayonet point',
#  'damietta',
#  'jesup',
#  'ulaangom',
#  'san francisco',
#  'bosaso',
#  'bar harbor',
#  'kumo',
#  'hoganas',
#  'kholodnyy',
#  'khonuu',
#  'aberchirder',
#  'ankazoabo',
#  'komsomolskiy',
#  'urubicha',
#  'dire',
#  'inirida',
#  'tumannyy',
#  'kutum',
#  'walvis bay',
#  'rogatica',
#  'cherkasskoye',
#  'florianopolis',
#  'primorsk',
#  'figeac',
#  'miraflores',
#  'turochak',
#  'kuche',
#  'podor',
#  'keuruu',
#  'elmadag',
#  'meulaboh',
#  'lar gerd',
#  'lucapa',
#  'cruzeiro',
#  'hyvinkaa',
#  'muravlenko',
#  'bambous virieux',
#  'puerto escondido',
#  'muli',
#  'opuwo',
#  'suihua',
#  'dholka',
#  'kot addu',
#  'pacifica',
#  'irbil',
#  'kosonsoy',
#  'umred',
#  'umm lajj',
#  'alyangula',
#  'marienburg',
#  'villa altagracia',
#  'susanino',
#  'dhidhdhoo',
#  'half moon bay',
#  'ballina',
#  'igrim',
#  'tommot',
#  'chikwawa',
#  'challapata',
#  'xuddur',
#  'acarau',
#  'toora-khem',
#  'belaya gora',
#  'ahar',
#  'dondo',
#  'canton',
#  'villena',
#  'kollo',
#  'mount isa',
#  'honiara',
#  'arti',
#  'mikuni',
#  'alberton',
#  'sangar',
#  'severo-yeniseyskiy',
#  'santa vitoria do palmar',
#  'marsh harbour',
#  'flinders',
#  'newport',
#  'moerai',
#  'chingirlau',
#  'vila franca do campo',
#  'portoferraio',
#  'huamantla',
#  'grimari',
#  'sao joao da barra',
#  'madimba',
#  'shache',
#  'locri',
#  'chulumani',
#  'la ronge',
#  'hay river',
#  'bodden town',
#  'falealupo',
#  'retie']

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | bandarbeyla
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | juxian
# City not found. Skipping...
# Processing Record 9 of Set 1 | dzaoudzi
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | wonthaggi
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 1 | guarapari
# Processing Record 17 of Set 1 | chunoyar
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | angoche
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | rostaq
# City not found. Skipping...
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | ercis
# Processing Record 24 of Set 1 | acapulco
# Processing Record 25 of Set 1 | nhulunbuy
# Processing Record 26 of Set 1 | menomonie
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | simpang
# Processing Record 30 of Set 1 | san cristobal
# Processing Record 31 of Set 1 | kloulklubed
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | la union
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | pavlodar
# Processing Record 39 of Set 1 | inuvik
# Processing Record 40 of Set 1 | vikindu
# Processing Record 41 of Set 1 | port hawkesbury
# Processing Record 42 of Set 1 | kudahuvadhoo
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | porbandar
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | zhanaozen
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | tabou
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | lorengau
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | racaciuni
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | gunjur
# Processing Record 16 of Set 2 | avera
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | thaton
# Processing Record 19 of Set 2 | svetlyy
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | krasnoselkup
# Processing Record 25 of Set 2 | ust-tsilma
# Processing Record 26 of Set 2 | gawler
# Processing Record 27 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 2 | sloboda
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | sola
# Processing Record 31 of Set 2 | vilyuysk
# Processing Record 32 of Set 2 | kaka
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | rokytne
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 42 of Set 2 | brae
# Processing Record 43 of Set 2 | tura
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | mocuba
# Processing Record 46 of Set 2 | moissac
# Processing Record 47 of Set 2 | maniitsoq
# Processing Record 48 of Set 2 | upata
# Processing Record 49 of Set 2 | mitsamiouli
# Processing Record 50 of Set 2 | goroka
# Processing Record 1 of Set 3 | tres arroyos
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | vung tau
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | groningen
# Processing Record 6 of Set 3 | barcelona
# Processing Record 7 of Set 3 | victor harbor
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | bambanglipuro
# Processing Record 10 of Set 3 | pafos
# Processing Record 11 of Set 3 | amurzet
# Processing Record 12 of Set 3 | znamenskoye
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | perth
# Processing Record 15 of Set 3 | metro
# Processing Record 16 of Set 3 | comodoro rivadavia
# Processing Record 17 of Set 3 | vallenar
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | lagoa
# Processing Record 20 of Set 3 | chapleau
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | gualaquiza
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | labuhan
# Processing Record 27 of Set 3 | tezu
# Processing Record 28 of Set 3 | colac
# Processing Record 29 of Set 3 | shenkursk
# Processing Record 30 of Set 3 | abalak
# Processing Record 31 of Set 3 | san nicolas
# Processing Record 32 of Set 3 | yelan-kolenovskiy
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | taft
# Processing Record 35 of Set 3 | uribia
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | duku
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | albany
# Processing Record 41 of Set 3 | coahuayana
# Processing Record 42 of Set 3 | ketou
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | pisco
# Processing Record 45 of Set 3 | turje
# Processing Record 46 of Set 3 | ca mau
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | kijang
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | cairns
# Processing Record 1 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | catuday
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | penzance
# Processing Record 9 of Set 4 | puerto ayora
# Processing Record 10 of Set 4 | kharian
# Processing Record 11 of Set 4 | inhambane
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | hualmay
# Processing Record 14 of Set 4 | sandusky
# Processing Record 15 of Set 4 | kintinku
# Processing Record 16 of Set 4 | torbay
# Processing Record 17 of Set 4 | koumac
# Processing Record 18 of Set 4 | bireun
# Processing Record 19 of Set 4 | tessalit
# Processing Record 20 of Set 4 | broome
# Processing Record 21 of Set 4 | ankpa
# Processing Record 22 of Set 4 | bontang
# Processing Record 23 of Set 4 | poso
# Processing Record 24 of Set 4 | prince rupert
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | peleduy
# Processing Record 27 of Set 4 | sioux lookout
# Processing Record 28 of Set 4 | burnie
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | varkkallai
# Processing Record 31 of Set 4 | pemberton
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | saldanha
# Processing Record 34 of Set 4 | impfondo
# Processing Record 35 of Set 4 | moosomin
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | hirara
# Processing Record 39 of Set 4 | west wendover
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | jahrom
# City not found. Skipping...
# Processing Record 42 of Set 4 | corozal
# Processing Record 43 of Set 4 | kumluca
# Processing Record 44 of Set 4 | antofagasta
# Processing Record 45 of Set 4 | borogontsy
# Processing Record 46 of Set 4 | ovsyanka
# Processing Record 47 of Set 4 | presidente dutra
# Processing Record 48 of Set 4 | egvekinot
# Processing Record 49 of Set 4 | kazanskaya
# Processing Record 50 of Set 4 | bredasdorp
# Processing Record 1 of Set 5 | trinidad
# Processing Record 2 of Set 5 | christchurch
# Processing Record 3 of Set 5 | forecariah
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | tyup
# Processing Record 6 of Set 5 | kamaishi
# Processing Record 7 of Set 5 | ahipara
# Processing Record 8 of Set 5 | amuntai
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | wanning
# Processing Record 11 of Set 5 | qarchi gak
# Processing Record 12 of Set 5 | elizabeth city
# Processing Record 13 of Set 5 | tahta
# Processing Record 14 of Set 5 | skjervoy
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | vao
# Processing Record 17 of Set 5 | waipawa
# Processing Record 18 of Set 5 | lamar
# Processing Record 19 of Set 5 | qaanaaq
# Processing Record 20 of Set 5 | pointe-noire
# Processing Record 21 of Set 5 | solano
# Processing Record 22 of Set 5 | baoding
# Processing Record 23 of Set 5 | sibolga
# Processing Record 24 of Set 5 | tarko-sale
# Processing Record 25 of Set 5 | tukrah
# Processing Record 26 of Set 5 | bonavista
# Processing Record 27 of Set 5 | junin
# Processing Record 28 of Set 5 | thompson
# Processing Record 29 of Set 5 | teya
# Processing Record 30 of Set 5 | beringovskiy
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | souillac
# Processing Record 34 of Set 5 | vilhena
# Processing Record 35 of Set 5 | altay
# Processing Record 36 of Set 5 | gollere
# City not found. Skipping...
# Processing Record 37 of Set 5 | adrar
# Processing Record 38 of Set 5 | vuktyl
# Processing Record 39 of Set 5 | basoko
# Processing Record 40 of Set 5 | bilibino
# Processing Record 41 of Set 5 | sukhobuzimskoye
# Processing Record 42 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 5 | callaway
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | pangai
# Processing Record 46 of Set 5 | la primavera
# Processing Record 47 of Set 5 | escanaba
# Processing Record 48 of Set 5 | margate
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 50 of Set 5 | moree
# Processing Record 1 of Set 6 | puro
# Processing Record 2 of Set 6 | kirakira
# Processing Record 3 of Set 6 | kieta
# Processing Record 4 of Set 6 | taltal
# Processing Record 5 of Set 6 | chipinge
# Processing Record 6 of Set 6 | lexington
# Processing Record 7 of Set 6 | high level
# Processing Record 8 of Set 6 | valdivia
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | gisborne
# Processing Record 11 of Set 6 | umm kaddadah
# Processing Record 12 of Set 6 | port alfred
# Processing Record 13 of Set 6 | san patricio
# Processing Record 14 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 6 | cidreira
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | channel-port aux basques
# Processing Record 18 of Set 6 | tutoia
# Processing Record 19 of Set 6 | songling
# Processing Record 20 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 6 | saskylakh
# Processing Record 22 of Set 6 | saint-georges
# Processing Record 23 of Set 6 | lishui
# Processing Record 24 of Set 6 | arman
# Processing Record 25 of Set 6 | gilgit
# Processing Record 26 of Set 6 | lebu
# Processing Record 27 of Set 6 | djougou
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | huilong
# Processing Record 30 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 6 | chara
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | pevek
# Processing Record 34 of Set 6 | healdsburg
# Processing Record 35 of Set 6 | robertson
# Processing Record 36 of Set 6 | naryan-mar
# Processing Record 37 of Set 6 | farah
# Processing Record 38 of Set 6 | ust-kut
# Processing Record 39 of Set 6 | nantucket
# Processing Record 40 of Set 6 | lhuntshi
# City not found. Skipping...
# Processing Record 41 of Set 6 | soroti
# Processing Record 42 of Set 6 | liaocheng
# Processing Record 43 of Set 6 | homer
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 6 | usinsk
# Processing Record 47 of Set 6 | mana
# Processing Record 48 of Set 6 | rincon
# Processing Record 49 of Set 6 | dombarovskiy
# Processing Record 50 of Set 6 | mandalgovi
# Processing Record 1 of Set 7 | whitehorse
# Processing Record 2 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 7 | caxito
# Processing Record 4 of Set 7 | harper
# Processing Record 5 of Set 7 | namyslow
# Processing Record 6 of Set 7 | plettenberg bay
# Processing Record 7 of Set 7 | saint anthony
# Processing Record 8 of Set 7 | uige
# Processing Record 9 of Set 7 | biga
# Processing Record 10 of Set 7 | hobyo
# Processing Record 11 of Set 7 | takoradi
# Processing Record 12 of Set 7 | maragogi
# Processing Record 13 of Set 7 | urengoy
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 16 of Set 7 | kununurra
# Processing Record 17 of Set 7 | sur
# Processing Record 18 of Set 7 | itarema
# Processing Record 19 of Set 7 | broken hill
# Processing Record 20 of Set 7 | klyuchi
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | veraval
# Processing Record 23 of Set 7 | georgetown
# Processing Record 24 of Set 7 | korkino
# Processing Record 25 of Set 7 | ucluelet
# Processing Record 26 of Set 7 | mackay
# Processing Record 27 of Set 7 | krasnoborsk
# Processing Record 28 of Set 7 | kangaatsiaq
# Processing Record 29 of Set 7 | staraya russa
# Processing Record 30 of Set 7 | aykhal
# Processing Record 31 of Set 7 | warwick
# Processing Record 32 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 7 | thai nguyen
# Processing Record 34 of Set 7 | cartagena del chaira
# Processing Record 35 of Set 7 | general pico
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | ust-nera
# Processing Record 38 of Set 7 | ye
# City not found. Skipping...
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | hastings
# Processing Record 41 of Set 7 | vila do maio
# Processing Record 42 of Set 7 | milan
# Processing Record 43 of Set 7 | palmer
# Processing Record 44 of Set 7 | motygino
# Processing Record 45 of Set 7 | zonguldak
# Processing Record 46 of Set 7 | dikson
# Processing Record 47 of Set 7 | zlatoust
# Processing Record 48 of Set 7 | nouadhibou
# Processing Record 49 of Set 7 | owando
# Processing Record 50 of Set 7 | kilindoni
# Processing Record 1 of Set 8 | turukhansk
# Processing Record 2 of Set 8 | boundiali
# Processing Record 3 of Set 8 | mashhad
# Processing Record 4 of Set 8 | aswan
# Processing Record 5 of Set 8 | jiexiu
# Processing Record 6 of Set 8 | vacaria
# Processing Record 7 of Set 8 | hambantota
# Processing Record 8 of Set 8 | scarborough
# Processing Record 9 of Set 8 | bay roberts
# Processing Record 10 of Set 8 | yulara
# Processing Record 11 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 8 | bathsheba
# Processing Record 14 of Set 8 | tettnang
# Processing Record 15 of Set 8 | maxixe
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | vardo
# Processing Record 18 of Set 8 | monterey
# Processing Record 19 of Set 8 | anshun
# Processing Record 20 of Set 8 | norman wells
# Processing Record 21 of Set 8 | piedras negras
# Processing Record 22 of Set 8 | bollnas
# Processing Record 23 of Set 8 | nizhniy kuranakh
# Processing Record 24 of Set 8 | cadiz
# Processing Record 25 of Set 8 | las cruces
# Processing Record 26 of Set 8 | mozarlandia
# Processing Record 27 of Set 8 | bata
# Processing Record 28 of Set 8 | guararapes
# Processing Record 29 of Set 8 | matadi
# Processing Record 30 of Set 8 | hasaki
# Processing Record 31 of Set 8 | voiron
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | manoharpur
# Processing Record 34 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 8 | biggar
# Processing Record 36 of Set 8 | cooma
# Processing Record 37 of Set 8 | northam
# Processing Record 38 of Set 8 | conceicao do araguaia
# Processing Record 39 of Set 8 | pitimbu
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | badarpur
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | atambua
# Processing Record 45 of Set 8 | aksaray
# Processing Record 46 of Set 8 | nanortalik
# Processing Record 47 of Set 8 | kalabo
# Processing Record 48 of Set 8 | iquitos
# Processing Record 49 of Set 8 | tiznit
# Processing Record 50 of Set 8 | rio grande
# Processing Record 1 of Set 9 | russell
# Processing Record 2 of Set 9 | biak
# Processing Record 3 of Set 9 | nahrin
# Processing Record 4 of Set 9 | pangnirtung
# Processing Record 5 of Set 9 | tecoanapa
# Processing Record 6 of Set 9 | smiltene
# Processing Record 7 of Set 9 | bulawayo
# Processing Record 8 of Set 9 | ayan
# Processing Record 9 of Set 9 | wahiawa
# Processing Record 10 of Set 9 | del rio
# Processing Record 11 of Set 9 | ekibastuz
# Processing Record 12 of Set 9 | lazaro cardenas
# Processing Record 13 of Set 9 | krasnogorodsk
# Processing Record 14 of Set 9 | graham
# Processing Record 15 of Set 9 | mildura
# Processing Record 16 of Set 9 | tautira
# Processing Record 17 of Set 9 | kendal
# Processing Record 18 of Set 9 | muroto
# Processing Record 19 of Set 9 | zyryanovsk
# Processing Record 20 of Set 9 | luanda
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | bilma
# Processing Record 24 of Set 9 | acajutla
# Processing Record 25 of Set 9 | westport
# Processing Record 26 of Set 9 | vytegra
# Processing Record 27 of Set 9 | panaba
# Processing Record 28 of Set 9 | cherlak
# Processing Record 29 of Set 9 | robertsport
# Processing Record 30 of Set 9 | zambezi
# Processing Record 31 of Set 9 | sokoni
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | marang
# Processing Record 34 of Set 9 | port lincoln
# Processing Record 35 of Set 9 | leh
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | bang saphan
# Processing Record 39 of Set 9 | novikovo
# Processing Record 40 of Set 9 | steamboat springs
# Processing Record 41 of Set 9 | marawi
# Processing Record 42 of Set 9 | anadyr
# Processing Record 43 of Set 9 | nemuro
# Processing Record 44 of Set 9 | pekan
# Processing Record 45 of Set 9 | ndele
# Processing Record 46 of Set 9 | qui nhon
# Processing Record 47 of Set 9 | argelia
# Processing Record 48 of Set 9 | araouane
# Processing Record 49 of Set 9 | kargasok
# Processing Record 50 of Set 9 | malanje
# Processing Record 1 of Set 10 | asau
# Processing Record 2 of Set 10 | aracuai
# Processing Record 3 of Set 10 | jutai
# Processing Record 4 of Set 10 | venice
# Processing Record 5 of Set 10 | mount pleasant
# Processing Record 6 of Set 10 | coquimbo
# Processing Record 7 of Set 10 | fare
# Processing Record 8 of Set 10 | sretensk
# Processing Record 9 of Set 10 | mahajanga
# Processing Record 10 of Set 10 | caucasia
# Processing Record 11 of Set 10 | makushino
# Processing Record 12 of Set 10 | bojaya
# City not found. Skipping...
# Processing Record 13 of Set 10 | makakilo city
# Processing Record 14 of Set 10 | boshnyakovo
# Processing Record 15 of Set 10 | lakes entrance
# Processing Record 16 of Set 10 | becerril
# Processing Record 17 of Set 10 | aklavik
# Processing Record 18 of Set 10 | peque
# Processing Record 19 of Set 10 | bajil
# Processing Record 20 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 10 | north berwick
# Processing Record 22 of Set 10 | bintulu
# Processing Record 23 of Set 10 | aleksandrovskiy zavod
# Processing Record 24 of Set 10 | san matias
# Processing Record 25 of Set 10 | kalanchak
# Processing Record 26 of Set 10 | kishi
# Processing Record 27 of Set 10 | tigil
# Processing Record 28 of Set 10 | bowen
# Processing Record 29 of Set 10 | ulundi
# Processing Record 30 of Set 10 | baghdad
# Processing Record 31 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 10 | iqaluit
# Processing Record 33 of Set 10 | kibiti
# Processing Record 34 of Set 10 | rossland
# Processing Record 35 of Set 10 | rosetta
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | mataram
# Processing Record 38 of Set 10 | kerur
# Processing Record 39 of Set 10 | kaitangata
# Processing Record 40 of Set 10 | mulege
# Processing Record 41 of Set 10 | touros
# Processing Record 42 of Set 10 | erzin
# Processing Record 43 of Set 10 | lloydminster
# Processing Record 44 of Set 10 | mosquera
# Processing Record 45 of Set 10 | eyl
# Processing Record 46 of Set 10 | pacific grove
# Processing Record 47 of Set 10 | lagos
# Processing Record 48 of Set 10 | bom jardim
# Processing Record 49 of Set 10 | dingle
# Processing Record 50 of Set 10 | karratha
# Processing Record 1 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 11 | puerto leguizamo
# Processing Record 3 of Set 11 | vanimo
# Processing Record 4 of Set 11 | tatarsk
# Processing Record 5 of Set 11 | general roca
# Processing Record 6 of Set 11 | susangerd
# Processing Record 7 of Set 11 | kavieng
# Processing Record 8 of Set 11 | gravdal
# Processing Record 9 of Set 11 | lufilufi
# Processing Record 10 of Set 11 | maningrida
# Processing Record 11 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | te anau
# Processing Record 13 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 11 | baykit
# Processing Record 15 of Set 11 | russkaya polyana
# Processing Record 16 of Set 11 | solvychegodsk
# Processing Record 17 of Set 11 | zhigansk
# Processing Record 18 of Set 11 | jiazi
# Processing Record 19 of Set 11 | campoverde
# Processing Record 20 of Set 11 | guiyang
# Processing Record 21 of Set 11 | pirgos
# Processing Record 22 of Set 11 | mackenzie
# Processing Record 23 of Set 11 | arlit
# Processing Record 24 of Set 11 | chumikan
# Processing Record 25 of Set 11 | gat
# Processing Record 26 of Set 11 | wenling
# Processing Record 27 of Set 11 | havelock
# Processing Record 28 of Set 11 | mecca
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | mogadishu
# Processing Record 31 of Set 11 | tonantins
# Processing Record 32 of Set 11 | sharjah
# Processing Record 33 of Set 11 | umarkot
# Processing Record 34 of Set 11 | tamandare
# Processing Record 35 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | el wasta
# City not found. Skipping...
# Processing Record 37 of Set 11 | praia
# Processing Record 38 of Set 11 | pemangkat
# Processing Record 39 of Set 11 | kota kinabalu
# Processing Record 40 of Set 11 | shingu
# Processing Record 41 of Set 11 | padang
# Processing Record 42 of Set 11 | dutse
# Processing Record 43 of Set 11 | ranau
# Processing Record 44 of Set 11 | hereford
# Processing Record 45 of Set 11 | belmonte
# Processing Record 46 of Set 11 | abha
# Processing Record 47 of Set 11 | portland
# Processing Record 48 of Set 11 | quepos
# Processing Record 49 of Set 11 | zhezkazgan
# Processing Record 50 of Set 11 | ibra
# Processing Record 1 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | prado
# Processing Record 3 of Set 12 | mugla
# Processing Record 4 of Set 12 | ewa beach
# Processing Record 5 of Set 12 | cururupu
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | soyo
# Processing Record 8 of Set 12 | mora
# Processing Record 9 of Set 12 | hailun
# Processing Record 10 of Set 12 | mujiayingzi
# Processing Record 11 of Set 12 | dunedin
# Processing Record 12 of Set 12 | baijiantan
# Processing Record 13 of Set 12 | cherskiy
# Processing Record 14 of Set 12 | elko
# Processing Record 15 of Set 12 | belyy yar
# Processing Record 16 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 17 of Set 12 | novyye burasy
# Processing Record 18 of Set 12 | rawson
# Processing Record 19 of Set 12 | haimen
# Processing Record 20 of Set 12 | kholtoson
# Processing Record 21 of Set 12 | burgas
# Processing Record 22 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 12 | severodvinsk
# Processing Record 25 of Set 12 | gedzhukh
# Processing Record 26 of Set 12 | safford
# Processing Record 27 of Set 12 | tambura
# Processing Record 28 of Set 12 | rapid valley
# Processing Record 29 of Set 12 | tiarei
# Processing Record 30 of Set 12 | cayenne
# Processing Record 31 of Set 12 | byron bay
# Processing Record 32 of Set 12 | galle
# Processing Record 33 of Set 12 | mongo
# Processing Record 34 of Set 12 | ituporanga
# Processing Record 35 of Set 12 | sechura
# Processing Record 36 of Set 12 | topolobampo
# Processing Record 37 of Set 12 | port blair
# Processing Record 38 of Set 12 | sao jose da coroa grande
# Processing Record 39 of Set 12 | port hope
# Processing Record 40 of Set 12 | nezahualcoyotl
# City not found. Skipping...
# Processing Record 41 of Set 12 | nizwa
# Processing Record 42 of Set 12 | kumbo
# Processing Record 43 of Set 12 | baturaja
# Processing Record 44 of Set 12 | jacareacanga
# Processing Record 45 of Set 12 | yaan
# Processing Record 46 of Set 12 | sharkan
# Processing Record 47 of Set 12 | pau brasil
# Processing Record 48 of Set 12 | cape canaveral
# Processing Record 49 of Set 12 | grand gaube
# Processing Record 50 of Set 12 | doha
# Processing Record 1 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 13 | bharatpur
# Processing Record 3 of Set 13 | edirne
# Processing Record 4 of Set 13 | ngunguru
# Processing Record 5 of Set 13 | oktyabrskiy
# Processing Record 6 of Set 13 | balaipungut
# Processing Record 7 of Set 13 | nelson bay
# Processing Record 8 of Set 13 | lasa
# Processing Record 9 of Set 13 | kabansk
# Processing Record 10 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 13 | kushiro
# Processing Record 12 of Set 13 | mayo
# Processing Record 13 of Set 13 | columbus
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | bagdarin
# Processing Record 16 of Set 13 | kharan
# Processing Record 17 of Set 13 | hudson bay
# Processing Record 18 of Set 13 | richards bay
# Processing Record 19 of Set 13 | lugazi
# Processing Record 20 of Set 13 | vazhiny
# Processing Record 21 of Set 13 | sao filipe
# Processing Record 22 of Set 13 | alexandria
# Processing Record 23 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 13 | oranjestad
# Processing Record 25 of Set 13 | karangasem
# Processing Record 26 of Set 13 | kaa-khem
# Processing Record 27 of Set 13 | kangavar
# Processing Record 28 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 13 | auki
# Processing Record 30 of Set 13 | kaspiyskiy
# Processing Record 31 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 32 of Set 13 | wladyslawowo
# Processing Record 33 of Set 13 | charlestown
# Processing Record 34 of Set 13 | sao paulo de olivenca
# Processing Record 35 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 13 | inverell
# Processing Record 37 of Set 13 | tomatlan
# Processing Record 38 of Set 13 | babati
# Processing Record 39 of Set 13 | samarai
# Processing Record 40 of Set 13 | lingao
# Processing Record 41 of Set 13 | ancud
# Processing Record 42 of Set 13 | marystown
# Processing Record 43 of Set 13 | itoman
# Processing Record 44 of Set 13 | gorontalo
# Processing Record 45 of Set 13 | north bay
# Processing Record 46 of Set 13 | canico
# Processing Record 47 of Set 13 | kirchlengern
# Processing Record 48 of Set 13 | ust-maya
# Processing Record 49 of Set 13 | pimentel
# Processing Record 50 of Set 13 | tilichiki
# Processing Record 1 of Set 14 | benguela
# Processing Record 2 of Set 14 | emporia
# Processing Record 3 of Set 14 | yakima
# Processing Record 4 of Set 14 | la paz
# Processing Record 5 of Set 14 | natal
# Processing Record 6 of Set 14 | salinopolis
# Processing Record 7 of Set 14 | san ramon
# Processing Record 8 of Set 14 | khandyga
# Processing Record 9 of Set 14 | zachepylivka
# Processing Record 10 of Set 14 | guaranda
# Processing Record 11 of Set 14 | qaqortoq
# Processing Record 12 of Set 14 | morlaix
# Processing Record 13 of Set 14 | waingapu
# Processing Record 14 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 15 of Set 14 | urusha
# Processing Record 16 of Set 14 | dawson
# Processing Record 17 of Set 14 | shimoda
# Processing Record 18 of Set 14 | los llanos de aridane
# Processing Record 19 of Set 14 | rundu
# Processing Record 20 of Set 14 | tabuk
# Processing Record 21 of Set 14 | nandura
# Processing Record 22 of Set 14 | nyurba
# Processing Record 23 of Set 14 | nizhniy odes
# Processing Record 24 of Set 14 | muzhi
# Processing Record 25 of Set 14 | cotija
# City not found. Skipping...
# Processing Record 26 of Set 14 | carmo do rio claro
# Processing Record 27 of Set 14 | meshchovsk
# Processing Record 28 of Set 14 | bayonet point
# Processing Record 29 of Set 14 | damietta
# Processing Record 30 of Set 14 | jesup
# Processing Record 31 of Set 14 | ulaangom
# Processing Record 32 of Set 14 | san francisco
# Processing Record 33 of Set 14 | bosaso
# Processing Record 34 of Set 14 | bar harbor
# Processing Record 35 of Set 14 | kumo
# Processing Record 36 of Set 14 | hoganas
# Processing Record 37 of Set 14 | kholodnyy
# Processing Record 38 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 14 | aberchirder
# Processing Record 40 of Set 14 | ankazoabo
# Processing Record 41 of Set 14 | komsomolskiy
# Processing Record 42 of Set 14 | urubicha
# Processing Record 43 of Set 14 | dire
# Processing Record 44 of Set 14 | inirida
# Processing Record 45 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 14 | kutum
# Processing Record 47 of Set 14 | walvis bay
# Processing Record 48 of Set 14 | rogatica
# Processing Record 49 of Set 14 | cherkasskoye
# Processing Record 50 of Set 14 | florianopolis
# Processing Record 1 of Set 15 | primorsk
# Processing Record 2 of Set 15 | figeac
# Processing Record 3 of Set 15 | miraflores
# Processing Record 4 of Set 15 | turochak
# Processing Record 5 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 15 | podor
# Processing Record 7 of Set 15 | keuruu
# Processing Record 8 of Set 15 | elmadag
# Processing Record 9 of Set 15 | meulaboh
# Processing Record 10 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 11 of Set 15 | lucapa
# Processing Record 12 of Set 15 | cruzeiro
# Processing Record 13 of Set 15 | hyvinkaa
# Processing Record 14 of Set 15 | muravlenko
# Processing Record 15 of Set 15 | bambous virieux
# Processing Record 16 of Set 15 | puerto escondido
# Processing Record 17 of Set 15 | muli
# Processing Record 18 of Set 15 | opuwo
# Processing Record 19 of Set 15 | suihua
# Processing Record 20 of Set 15 | dholka
# Processing Record 21 of Set 15 | kot addu
# Processing Record 22 of Set 15 | pacifica
# Processing Record 23 of Set 15 | irbil
# Processing Record 24 of Set 15 | kosonsoy
# Processing Record 25 of Set 15 | umred
# Processing Record 26 of Set 15 | umm lajj
# Processing Record 27 of Set 15 | alyangula
# Processing Record 28 of Set 15 | marienburg
# Processing Record 29 of Set 15 | villa altagracia
# Processing Record 30 of Set 15 | susanino
# Processing Record 31 of Set 15 | dhidhdhoo
# Processing Record 32 of Set 15 | half moon bay
# Processing Record 33 of Set 15 | ballina
# Processing Record 34 of Set 15 | igrim
# Processing Record 35 of Set 15 | tommot
# Processing Record 36 of Set 15 | chikwawa
# Processing Record 37 of Set 15 | challapata
# Processing Record 38 of Set 15 | xuddur
# Processing Record 39 of Set 15 | acarau
# Processing Record 40 of Set 15 | toora-khem
# Processing Record 41 of Set 15 | belaya gora
# Processing Record 42 of Set 15 | ahar
# Processing Record 43 of Set 15 | dondo
# Processing Record 44 of Set 15 | canton
# Processing Record 45 of Set 15 | villena
# Processing Record 46 of Set 15 | kollo
# Processing Record 47 of Set 15 | mount isa
# Processing Record 48 of Set 15 | honiara
# Processing Record 49 of Set 15 | arti
# Processing Record 50 of Set 15 | mikuni
# Processing Record 1 of Set 16 | alberton
# Processing Record 2 of Set 16 | sangar
# Processing Record 3 of Set 16 | severo-yeniseyskiy
# Processing Record 4 of Set 16 | santa vitoria do palmar
# Processing Record 5 of Set 16 | marsh harbour
# Processing Record 6 of Set 16 | flinders
# Processing Record 7 of Set 16 | newport
# Processing Record 8 of Set 16 | moerai
# Processing Record 9 of Set 16 | chingirlau
# Processing Record 10 of Set 16 | vila franca do campo
# Processing Record 11 of Set 16 | portoferraio
# Processing Record 12 of Set 16 | huamantla
# Processing Record 13 of Set 16 | grimari
# City not found. Skipping...
# Processing Record 14 of Set 16 | sao joao da barra
# Processing Record 15 of Set 16 | madimba
# Processing Record 16 of Set 16 | shache
# Processing Record 17 of Set 16 | locri
# Processing Record 18 of Set 16 | chulumani
# Processing Record 19 of Set 16 | la ronge
# Processing Record 20 of Set 16 | hay river
# Processing Record 21 of Set 16 | bodden town
# Processing Record 22 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 16 | retie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Lavrentiya  65.5833 -171.0000    -10.34        90           7
# 1    Mar Del Plata -38.0023  -57.5575     62.87        75          40
# 2      Bandarbeyla   9.4942   50.8122     74.19        73         100
# 3            Vaini -21.2000 -175.2000     87.96        79          20
# 4       Chokurdakh  70.6333  147.9167     -2.51        96         100
# ..             ...      ...       ...       ...       ...         ...
# 706      Chulumani -16.4096  -67.5263     64.44        98         100
# 707       La Ronge  55.1001 -105.2842    -12.75        77          40
# 708      Hay River  60.8156 -115.7999     -0.42        85         100
# 709    Bodden Town  19.2833  -81.2500     79.00        78          20
# 710          Retie  51.2666    5.0839     37.78        72          51
#
#      Wind Speed Current Description
# 0          6.91           clear sky
# 1          7.00    scattered clouds
# 2         11.95     overcast clouds
# 3         10.36          few clouds
# 4         12.08     overcast clouds
# ..          ...                 ...
# 706        1.54          light rain
# 707        3.44    scattered clouds
# 708       12.66          light snow
# 709        5.75          few clouds
# 710       10.83       broken clouds
#
# [711 rows x 8 columns]

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
